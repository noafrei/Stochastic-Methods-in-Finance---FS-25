# %% [markdown]
#  # Stochastic Methods in Finance

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
s

# %% [markdown]
# ## Importing and inspecting the dataset

# %%
data = pd.read_csv("/Users/ludozzi/Visual Studio Code/Stochastic Methods in Finance/HistoricalData_1745936412120.csv")
data.head()
# I want to summarise the characteristics of the data
data.describe()

#test add some modifications
# Out:
#              Volume
# count  2.515000e+03
# mean   2.832708e+07
# std    1.273265e+07
# min    7.164543e+06
# 25%    2.027294e+07
# 50%    2.522276e+07
# 75%    3.268094e+07
# max    1.351529e+08
